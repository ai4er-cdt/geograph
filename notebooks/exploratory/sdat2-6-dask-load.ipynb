# %%
# Convenient jupyter setup
# %load_ext autoreload
# %autoreload 2
# %config IPCompleter.greedy=True

# %%
import os
import dask
import dask.array as da
from dask.distributed import Client
import xarray as xr
from src.constants import SAT_DIR
from src.preprocessing.load_landsat_esa import clip, return_xy_dask
# Out:
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'

# %%
client = Client(n_workers=12, threads_per_worker=10, memory_limit="10GB")
# Out:
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# /home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/node.py:151: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 35183 instead
#   warnings.warn(
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
# ...
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'
# tornado.application - ERROR - Exception in callback <bound method Nanny.memory_monitor of <Nanny: None, threads: 4>>
# Traceback (most recent call last):
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/users/sithom/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/nanny.py", line 417, in memory_monitor
#     process = self.process.process
# AttributeError: 'NoneType' object has no attribute 'process'

# %%
client

# %%
# client = Client(n_workers=12, threads_per_worker=10, memory_limit="10GB")

# %%
ds = xr.tutorial.open_dataset(
    "air_temperature", 
    chunks='auto'
)

# %%
ds["air"]

# %%
input_direc = os.path.join(SAT_DIR, "inputs")

# %%
x_file_name = os.path.join(input_direc, "take_esa_coords_False_use_mfd_False_use_ffil_True_use_ir_False_x.nc")

# %%
y_file_name = "/gws/nopw/j04/ai4er/guided-team-challenge/2021/biodiversity/gee_satellite_data/inputs/take_esa_coords_False_use_mfd_False_use_ffil_False_use_ir_False_y.nc"

# %%
input_direc = os.path.join(SAT_DIR, "inputs")
x_file_name = os.path.join(input_direc, "take_esa_coords_False_use_mfd_False_use_ffil_True_use_ir_False_x.nc")
y_file_name = os.path.join(input_direc, "take_esa_coords_False_use_mfd_False_use_ffil_False_use_ir_False_y.nc")
x_da = xr.open_dataset(x_file_name, chunks={'year': 1, 'band': 1, 'mn': 1}).norm_refl
y_da = xr.open_dataset(y_file_name, chunks={'year': 1}).esa_cci
x_da, y_da = clip(x_da, y_da)
# Out:
# clipping
# before clipping, da_1 <xarray.DataArray 'norm_refl' (y: 7361, x: 11905, band: 3, year: 24, mn: 4)>
# dask.array<open_dataset-b8b9bb0f641f6bffcde688d236d2dd9cnorm_refl, shape=(7361, 11905, 3, 24, 4), dtype=float32, chunksize=(7361, 11905, 1, 1, 1), chunktype=numpy.ndarray>
# Coordinates:
#   * x        (x) float64 28.27 28.27 28.27 28.27 ... 31.47 31.47 31.47 31.47
#   * y        (y) float64 52.48 52.48 52.48 52.48 52.48 ... 50.5 50.5 50.5 50.5
#   * band     (band) object 'A' 'B' 'C'
#   * year     (year) int64 1992 1993 1994 1995 1996 ... 2011 2012 2013 2014 2015
#   * mn       (mn) object 'JFM' 'AMJ' 'JAS' 'OND'
# Attributes:
#     description:  Normalized reflectance at chernfor JFM. Bands order ['B3', ...
#     bands:        ['B3', 'B2', 'B1']
# after clipping, da_2 <xarray.DataArray 'esa_cci' (year: 24, y: 7009, x: 11184)>
# dask.array<open_dataset-4c13f22273ec07c953aeb17fe1eaca30esa_cci, shape=(24, 7009, 11184), dtype=uint8, chunksize=(1, 7009, 11184), chunktype=numpy.ndarray>
# Coordinates:
#   * x        (x) float64 28.41 28.41 28.41 28.41 ... 31.42 31.42 31.42 31.42
#   * y        (y) float64 52.43 52.43 52.43 52.43 ... 50.55 50.55 50.55 50.55
#     band     int64 ...
#   * year     (year) int64 1992 1993 1994 1995 1996 ... 2011 2012 2013 2014 2015
# Attributes:
#     transform:      [ 2.77777778e-03  0.00000000e+00  2.84055556e+01  0.00000...
#     crs:            +init=epsg:4326
#     res:            [0.00277778 0.00277778]
#     is_tiled:       0
#     nodatavals:     0.0
#     scales:         1.0
#     offsets:        0.0
#     AREA_OR_POINT:  Area
# 'clip'  0.15558 s

# %%
ls -lash /gws/nopw/j04/ai4er/guided-team-challenge/2021/biodiversity/gee_satellite_data/inputs
# Out:
# total 36G
#    0 drwxr-sr-x 1 sithom gws_ai4er    0 Mar 12 09:36 ./
#    0 drwxrwsr-- 1 svm    gws_ai4er    0 Mar 11 20:13 ../
# 227M -rw-r--r-- 1 sithom gws_ai4er 1.8G Mar 11 11:40 take_esa_coords_False_use_mfd_False_use_ffil_False_use_ir_False_y.nc
#  12G -rw-r--r-- 1 sithom gws_ai4er  95G Mar  4 21:03 take_esa_coords_False_use_mfd_False_use_ffil_True_use_ir_False_x.nc
# 227M -rw-r--r-- 1 sithom gws_ai4er 1.8G Mar 11 11:39 take_esa_coords_False_use_mfd_False_use_ffil_True_use_ir_False_y.nc
#  11G -rw-r--r-- 1 sithom gws_ai4er  85G Mar 12 04:17 take_esa_coords_False_use_mfd_True_use_ffil_True_use_ir_False_x.nc
# 227M -rw-r--r-- 1 sithom gws_ai4er 1.8G Mar 11 11:35 take_esa_coords_False_use_mfd_True_use_ffil_True_use_ir_False_y.nc
#  12G -rw-r--r-- 1 sithom gws_ai4er  95G Mar  5 21:40 take_esa_coords_False_use_mfd_True_use_ffil_True_x.nc
# 2.2M -rw-r--r-- 1 sithom gws_ai4er  17M Mar 12 09:17 take_esa_coords_True_use_mfd_False_use_ffil_False_use_ir_False_y.nc
# 2.2M -rw-r--r-- 1 sithom gws_ai4er  17M Mar 12 09:36 take_esa_coords_True_use_mfd_False_use_ffil_False_use_ir_True_y.nc
# 103M -rw-r--r-- 1 sithom gws_ai4er 813M Mar 10 18:17 take_esa_coords_True_use_mfd_False_use_ffil_True_use_ir_False_x.nc
# 2.2M -rw-r--r-- 1 sithom gws_ai4er  17M Mar 12 09:17 take_esa_coords_True_use_mfd_False_use_ffil_True_use_ir_False_y.nc
# 205M -rw-r--r-- 1 sithom gws_ai4er 1.6G Mar  6 21:14 take_esa_coords_True_use_mfd_False_use_ffil_True_use_ir_True_x.nc
# 2.2M -rw-r--r-- 1 sithom gws_ai4er  17M Mar 12 09:36 take_esa_coords_True_use_mfd_False_use_ffil_True_use_ir_True_y.nc
# 103M -rw-r--r-- 1 sithom gws_ai4er 813M Mar  4 12:06 take_esa_coords_True_use_mfd_False_use_ffil_True_use_ir__x.nc
# 2.2M -rw-r--r-- 1 sithom gws_ai4er  17M Mar  4 12:06 take_esa_coords_True_use_mfd_False_use_ffil_True_use_ir__y.nc
# 103M -rw-r--r-- 1 sithom gws_ai4er 813M Mar  2 18:05 take_esa_coords_True_use_mfd_False_use_ffil_True_x.nc
# 2.2M -rw-r--r-- 1 sithom gws_ai4er  17M Mar  2 18:05 take_esa_coords_True_use_mfd_False_use_ffil_True_y.nc
# 103M -rw-r--r-- 1 sithom gws_ai4er 813M Mar 10 21:00 take_esa_coords_True_use_mfd_True_use_ffil_True_use_ir_False_x.nc
# 2.2M -rw-r--r-- 1 sithom gws_ai4er  17M Mar 10 21:00 take_esa_coords_True_use_mfd_True_use_ffil_True_use_ir_False_y.nc
#  23K -rw-r--r-- 1 sithom gws_ai4er  11K Mar  6 16:36 take_esa_coords_True_use_mfd_True_use_ffil_True_use_ir_True_x.nc
# 2.2M -rw-r--r-- 1 sithom gws_ai4er  17M Mar  6 13:07 take_esa_coords_True_use_mfd_True_use_ffil_True_use_ir_True_y.nc

# %%
x_da
# Out:
# <xarray.DataArray 'norm_refl' (y: 7009, x: 11184, band: 3, year: 24, mn: 4)>
# dask.array<getitem, shape=(7009, 11184, 3, 24, 4), dtype=float32, chunksize=(7009, 11184, 1, 1, 1), chunktype=numpy.ndarray>
# Coordinates:
#   * x        (x) float64 28.41 28.41 28.41 28.41 ... 31.42 31.42 31.42 31.42
#   * y        (y) float64 52.43 52.43 52.43 52.43 ... 50.55 50.55 50.55 50.55
#   * band     (band) object 'A' 'B' 'C'
#   * year     (year) int64 1992 1993 1994 1995 1996 ... 2011 2012 2013 2014 2015
#   * mn       (mn) object 'JFM' 'AMJ' 'JAS' 'OND'
# Attributes:
#     description:  Normalized reflectance at chernfor JFM. Bands order ['B3', ...
#     bands:        ['B3', 'B2', 'B1']

# %%
x_da
# Out:
# <xarray.DataArray 'norm_refl' (y: 7009, x: 11184, band: 3, year: 24, mn: 4)>
# dask.array<getitem, shape=(7009, 11184, 3, 24, 4), dtype=float32, chunksize=(7009, 11184, 1, 1, 1), chunktype=numpy.ndarray>
# Coordinates:
#   * x        (x) float64 28.41 28.41 28.41 28.41 ... 31.42 31.42 31.42 31.42
#   * y        (y) float64 52.43 52.43 52.43 52.43 ... 50.55 50.55 50.55 50.55
#   * band     (band) object 'A' 'B' 'C'
#   * year     (year) int64 1992 1993 1994 1995 1996 ... 2011 2012 2013 2014 2015
#   * mn       (mn) object 'JFM' 'AMJ' 'JAS' 'OND'
# Attributes:
#     description:  Normalized reflectance at chernfor JFM. Bands order ['B3', ...
#     bands:        ['B3', 'B2', 'B1']

# %%
y_da
# Out:
# <xarray.DataArray 'esa_cci' (year: 24, y: 7009, x: 11184)>
# dask.array<open_dataset-4c13f22273ec07c953aeb17fe1eaca30esa_cci, shape=(24, 7009, 11184), dtype=uint8, chunksize=(1, 7009, 11184), chunktype=numpy.ndarray>
# Coordinates:
#   * x        (x) float64 28.41 28.41 28.41 28.41 ... 31.42 31.42 31.42 31.42
#   * y        (y) float64 52.43 52.43 52.43 52.43 ... 50.55 50.55 50.55 50.55
#     band     int64 ...
#   * year     (year) int64 1992 1993 1994 1995 1996 ... 2011 2012 2013 2014 2015
# Attributes:
#     transform:      [ 2.77777778e-03  0.00000000e+00  2.84055556e+01  0.00000...
#     crs:            +init=epsg:4326
#     res:            [0.00277778 0.00277778]
#     is_tiled:       0
#     nodatavals:     0.0
#     scales:         1.0
#     offsets:        0.0
#     AREA_OR_POINT:  Area

# %%
def return_xy_npa(x_da, y_da, year=5):
    """
    return the x and y numpy arrays for a given number of years.
    Currently this function just returns (N, D) for x and (N,) for Y
    for UNET we want a function that returns (yr, y, xr, D) for x and (yr, y, x, D) for y
    :param x_da: xarray.dataarray, inputs
    :param y_da: xarray.dataarray, labels
    :param year: ints, single or list
    :return: x_val, y_val
    """

    def combine_first_two_indices(x_val, y_val):
        return (
            np.swapaxes(
                np.array([x_val[:, :, i].ravel() for i in range(x_val.shape[2])]), 0, 1
            ),
            y_val.ravel(),
        )

    def _return_xy_npa(x_da, y_da, yr=5):
        assert isinstance(yr, int)
        x_val = np.asarray(
            [
                x_da.isel(year=yr, mn=mn, band=band).values.ravel()
                for mn in range(len(x_da.mn.values))
                for band in range(len(x_da.band.values))
            ]
        )
        # [mn, band]
        return np.swapaxes(x_val, 0, 1), y_da.isel(year=yr).values.ravel()

    if isinstance(year, range) or isinstance(year, list):
        x_val_l, y_val_l = [], []
        for yr in year:
            x_val_p, y_val_p = _return_xy_npa(x_da, y_da, yr=yr)
            x_val_l.append(x_val_p)
            y_val_l.append(y_val_p)
        x_val, y_val = combine_first_two_indices(np.array(x_val_l), np.array(y_val_l))
    else:
        x_val, y_val = _return_xy_npa(x_da, y_da, yr=year)
    return x_val, y_val

# %%
x_val, y_val = return_xy_npa(x_da, y_da, year=5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-111-c6b1f93c782b> in <module>
# ----> 1 x_val, y_val = return_xy_npa(x_da, y_da, year=5)
#
# <ipython-input-54-2d78951031bf> in return_xy_npa(x_da, y_da, year)
#      38         x_val, y_val = combine_first_two_indices(np.array(x_val_l), np.array(y_val_l))
#      39     else:
# ---> 40         x_val, y_val = _return_xy_npa(x_da, y_da, yr=year)
#      41     return x_val, y_val
#
# <ipython-input-54-2d78951031bf> in _return_xy_npa(x_da, y_da, yr)
#      21         assert isinstance(yr, int)
#      22         x_val = np.asarray(
# ---> 23             [
#      24                 x_da.isel(year=yr, mn=mn, band=band).values.ravel()
#      25                 for mn in range(len(x_da.mn.values))
#
# <ipython-input-54-2d78951031bf> in <listcomp>(.0)
#      22         x_val = np.asarray(
#      23             [
# ---> 24                 x_da.isel(year=yr, mn=mn, band=band).values.ravel()
#      25                 for mn in range(len(x_da.mn.values))
#      26                 for band in range(len(x_da.band.values))
#
# ~/gtc-biodiversity/env/lib/python3.8/site-packages/xarray/core/dataarray.py in values(self)
#     632     def values(self) -> np.ndarray:
#     633         """The array's data as a numpy.ndarray"""
# --> 634         return self.variable.values
#     635
#     636     @values.setter
#
# ~/gtc-biodiversity/env/lib/python3.8/site-packages/xarray/core/variable.py in values(self)
#     552     def values(self):
#     553         """The variable's data as a numpy.ndarray"""
# --> 554         return _as_array_or_item(self._data)
#     555
#     556     @values.setter
#
# ~/gtc-biodiversity/env/lib/python3.8/site-packages/xarray/core/variable.py in _as_array_or_item(data)
#     285         data = data.get()
#     286     else:
# --> 287         data = np.asarray(data)
#     288     if data.ndim == 0:
#     289         if data.dtype.kind == "M":
#
# ~/gtc-biodiversity/env/lib/python3.8/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ~/gtc-biodiversity/env/lib/python3.8/site-packages/dask/array/core.py in __array__(self, dtype, **kwargs)
#    1481
#    1482     def __array__(self, dtype=None, **kwargs):
# -> 1483         x = self.compute()
#    1484         if dtype and x.dtype != dtype:
#    1485             x = x.astype(dtype)
#
# ~/gtc-biodiversity/env/lib/python3.8/site-packages/dask/base.py in compute(self, **kwargs)
#     281         dask.base.compute
#     282         """
# --> 283         (result,) = compute(self, traverse=False, **kwargs)
#     284         return result
#     285
#
# ~/gtc-biodiversity/env/lib/python3.8/site-packages/dask/base.py in compute(*args, **kwargs)
#     563         postcomputes.append(x.__dask_postcompute__())
#     564
# --> 565     results = schedule(dsk, keys, **kwargs)
#     566     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     567
#
# ~/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/client.py in get(self, dsk, keys, workers, allow_other_workers, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    2652                     should_rejoin = False
#    2653             try:
# -> 2654                 results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    2655             finally:
#    2656                 for f in futures.values():
#
# ~/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/client.py in gather(self, futures, errors, direct, asynchronous)
#    1961             else:
#    1962                 local_worker = None
# -> 1963             return self.sync(
#    1964                 self._gather,
#    1965                 futures,
#
# ~/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/client.py in sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     835             return future
#     836         else:
# --> 837             return sync(
#     838                 self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     839             )
#
# ~/gtc-biodiversity/env/lib/python3.8/site-packages/distributed/utils.py in sync(loop, func, callback_timeout, *args, **kwargs)
#     346     else:
#     347         while not e.is_set():
# --> 348             e.wait(10)
#     349     if error[0]:
#     350         typ, exc, tb = error[0]
#
# ~/gtc-biodiversity/env/lib/python3.8/threading.py in wait(self, timeout)
#     556             signaled = self._flag
#     557             if not signaled:
# --> 558                 signaled = self._cond.wait(timeout)
#     559             return signaled
#     560
#
# ~/gtc-biodiversity/env/lib/python3.8/threading.py in wait(self, timeout)
#     304             else:
#     305                 if timeout > 0:
# --> 306                     gotit = waiter.acquire(True, timeout)
#     307                 else:
#     308                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
x_da.isel(year=0, mn=0, band=0).data.ravel()
# Out:
# dask.array<reshape, shape=(87632705,), dtype=float32, chunksize=(87632705,), chunktype=numpy.ndarray>

# %%
x_da
# Out:
# <xarray.DataArray 'norm_refl' (y: 7361, x: 11905, band: 3, year: 24, mn: 4)>
# dask.array<open_dataset-b8b9bb0f641f6bffcde688d236d2dd9cnorm_refl, shape=(7361, 11905, 3, 24, 4), dtype=float32, chunksize=(7361, 11905, 1, 1, 1), chunktype=numpy.ndarray>
# Coordinates:
#   * x        (x) float64 28.27 28.27 28.27 28.27 ... 31.47 31.47 31.47 31.47
#   * y        (y) float64 52.48 52.48 52.48 52.48 52.48 ... 50.5 50.5 50.5 50.5
#   * band     (band) object 'A' 'B' 'C'
#   * year     (year) int64 1992 1993 1994 1995 1996 ... 2011 2012 2013 2014 2015
#   * mn       (mn) object 'JFM' 'AMJ' 'JAS' 'OND'
# Attributes:
#     description:  Normalized reflectance at chernfor JFM. Bands order ['B3', ...
#     bands:        ['B3', 'B2', 'B1']

# %%
x_val
# Out:
# dask.array<stack, shape=(78388656, 12), dtype=float32, chunksize=(78388656, 1), chunktype=numpy.ndarray>

# %%
y_da.isel(year=0).data.ravel()
# Out:
# dask.array<reshape, shape=(78388656,), dtype=uint8, chunksize=(78388656,), chunktype=numpy.ndarray>

# %%
def return_xy_dask(x_da, y_da, year=5):
    """
    return the x and y numpy arrays for a given number of years.
    Currently this function just returns (N, D) for x and (N,) for Y
    for UNET we want a function that returns (yr, y, xr, D) for x and (yr, y, x, D) for y
    :param x_da: xarray.DataArray, inputs
    :param y_da: xarray.DataArray, labels
    :param year: ints, single or list
    :return: x_val, y_val
    """

    def combine_first_two_indices(x_val, y_val):
        return (
            da.stack([x_val[:, :, i].ravel() for i in range(x_val.shape[2])], axis=1),
            y_val.ravel(),
        )

    def _return_xy_dask_array(x_da, y_da, yr=5):
        assert isinstance(yr, int)
        x_val = da.stack(
            [
                x_da.isel(year=0, mn=mn, band=band).data.ravel()
                for mn in range(len(x_da.mn.values))
                for band in range(len(x_da.band.values))
            ],
            axis=1,
        )  # [mn, band]
        return x_val, y_da.isel(year=yr).data.ravel()

    if isinstance(year, range) or isinstance(year, list):
        x_val_l, y_val_l = [], []
        for yr in year:
            x_val_p, y_val_p = _return_xy_dask_array(x_da, y_da, yr=yr)
            x_val_l.append(x_val_p)
            y_val_l.append(y_val_p)
        # x_val, y_val = da.stack(x_val_l), da.stack(y_val_l)
        x_val, y_val = combine_first_two_indices(da.stack(x_val_l), da.stack(y_val_l))
    else:
        x_val, y_val = _return_xy_dask_array(x_da, y_da, yr=year)
    return x_val, y_val

# %%
x_val, y_val = return_xy_dask(x_da, y_da, year=range(8, 19))

# %%
x_val
# Out:
# dask.array<stack, shape=(862275216, 12), dtype=float32, chunksize=(78388656, 1), chunktype=numpy.ndarray>

# %%
y_val
# Out:
# dask.array<reshape, shape=(862275216,), dtype=uint8, chunksize=(78388656,), chunktype=numpy.ndarray>
