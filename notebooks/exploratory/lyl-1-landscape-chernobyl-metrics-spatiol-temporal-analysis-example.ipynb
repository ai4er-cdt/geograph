# %%
import rasterio
from rasterio.plot import show
from rasterio.plot import show_hist
from rasterio.mask import mask
from shapely.geometry import box
import geopandas as gpd
from fiona.crs import from_epsg
import pycrs
import os
import pathlib
# %matplotlib inline

# %%
CEDA_DIR = pathlib.Path("/") / "neodc"
LANDCOVER_DIR = CEDA_DIR / "esacci" / "land_cover" / "data" / "land_cover_maps" / "v2.0.7"
# Load sample data file:
landcover_2015_path = LANDCOVER_DIR / "ESACCI-LC-L4-LCCS-Map-300m-P1Y-2015-v2.0.7.tif"

# %%
data = rasterio.open(landcover_2015_path)

# %%
print(data.bounds)
print(data.shape)
# Out:
# BoundingBox(left=-180.0, bottom=-90.00000000001438, right=180.00000000002876, top=90.0)
# (64800, 129600)

# %%
minx, miny = 30, 50.5
maxx, maxy = 31, 52
bbox = box(minx, miny, maxx, maxy)

# %%
geo = gpd.GeoDataFrame({'geometry': bbox}, index=[0], crs=from_epsg(4326))
# Out:
# /home/users/lyl1104/gtc-biodiversity/env/lib/python3.8/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
print(geo)
# Out:
#                                             geometry
# 0  POLYGON ((31.00000 50.50000, 31.00000 52.00000...

# %%
geo = geo.to_crs(crs=data.crs.data)

geo.crs
# Out:
# /home/users/lyl1104/gtc-biodiversity/env/lib/python3.8/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# <Geographic 2D CRS: +init=epsg:4326 +no_defs +type=crs>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - lon[east]: Longitude (degree)
# - lat[north]: Latitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
def getFeatures(gdf):
    '''Function to parse features from GeoDataFrame in such a manner that rasterio wants them'''
    import json
    return[json.loads(gdf.to_json())['features'][0]['geometry']]

# %%
#Get the geometry coordinates by using the function.
coords = getFeatures(geo)
print(coords)
# Out:
# [{'type': 'Polygon', 'coordinates': [[[31.0, 50.5], [31.0, 52.0], [30.0, 52.0], [30.0, 50.5], [31.0, 50.5]]]}]

# %%
# Clip the raster with Polygon
out_img, out_transform = mask(dataset=data, shapes=coords, crop=True)

# %%
# Copy the metadata
out_meta = data.meta.copy()
print(out_meta)
# Out:
# {'driver': 'GTiff', 'dtype': 'uint8', 'nodata': 0.0, 'width': 129600, 'height': 64800, 'count': 1, 'crs': CRS.from_epsg(4326), 'transform': Affine(0.002777777777778, 0.0, -180.0,
#        0.0, -0.002777777777778, 90.0)}

# %%
# Parse EPSG code
epsg_code = int(data.crs.data['init'][5:])
print(epsg_code)
# Out:
# 4326

# %%
out_meta.update({"driver": "GTiff",
                 "height": out_img.shape[1],
                 "width": out_img.shape[2],
                 "transform": out_transform,
                 "crs": pycrs.parse.from_epsg_code(epsg_code).to_proj4()}
                         )

# %%
out_tif = r"landcover_esacci_2015_cropped1.tif"
with rasterio.open(out_tif, "w", **out_meta) as dest:
        dest.write(out_img)

# %%
# Open the clipped raster file
clipped = rasterio.open(out_tif)

# Visualize
show((clipped)) #Chernobyl
# Out:
# <AxesSubplot:>

# %%
import pylandstats as pls

# %%
#Load output in pylandstats
ls=pls.Landscape(out_tif)

# %%
ls.plot_landscape(legend=True)
# Out:
# <AxesSubplot:>

# %%
#Calculate patch metrics using pylandstats
patch_metrics_df = ls.compute_patch_metrics_df()
patch_metrics_df.head()
# Out:
#           class_val          area  perimeter  perimeter_area_ratio  \
# patch_id
# 0                10  2.314815e-09   0.022222          9.600000e+06
# 1                10  1.543210e-09   0.016667          1.080000e+07
# 2                10  1.543210e-09   0.016667          1.080000e+07
# 3                10  1.543210e-09   0.016667          1.080000e+07
# 4                10  3.564815e-07   1.161111          3.257143e+06
#
#           shape_index  fractal_dimension  euclidean_nearest_neighbor
# patch_id
# 0            1.000000           0.973047                    0.008333
# 1            1.000000           0.989369                    0.008333
# 2            1.000000           0.989369                    0.010015
# 3            1.000000           0.989369                    0.008784
# 4            4.860465           0.438884                    0.005556

# %%
#Calculate class metrics using pylandstats
class_metrics_df = ls.compute_class_metrics_df()
class_metrics_df
# Out:
#              total_area  proportion_of_landscape  number_of_patches  \
# class_val
# 10         4.995139e-05                33.300926                698
# 11         7.078704e-06                 4.719136               1003
# 30         3.708333e-06                 2.472222               1275
# 40         7.731481e-07                 0.515432                432
# 60         8.750000e-06                 5.833333                647
# 61         3.163580e-08                 0.021091                 15
# 70         4.675849e-05                31.172325                585
# 90         6.247685e-06                 4.165123                736
# 100        5.307099e-06                 3.538066               1223
# 110        5.941358e-08                 0.039609                 10
# 130        6.267747e-06                 4.178498                588
# 150        4.012346e-08                 0.026749                 11
# 160        6.087963e-07                 0.405864                243
# 180        7.175926e-08                 0.047840                 42
# 190        3.255401e-06                 2.170267                322
# 200        3.086420e-09                 0.002058                  2
# 210        1.108719e-05                 7.391461                172
#
#            patch_density  largest_patch_index  total_edge   edge_density  \
# class_val
# 10          4.653333e+08            16.328704  134.902778  899351.851852
# 11          6.686667e+08             0.172325   45.516667  303444.444444
# 30          8.500000e+08             0.028807   34.950000  233000.000000
# 40          2.880000e+08             0.006687    8.311111   55407.407407
# 60          4.313333e+08             0.711934   36.650000  244333.333333
# 61          1.000000e+07             0.003086    0.322222    2148.148148
# 70          3.900000e+08             6.181584   92.938889  619592.592593
# 90          4.906667e+08             0.411008   39.450000  263000.000000
# 100         8.153333e+08             0.079733   42.363889  282425.925926
# 110         6.666667e+06             0.016975    0.311111    2074.074074
# 130         3.920000e+08             0.754115   33.200000  221333.333333
# 150         7.333333e+06             0.008230    0.311111    2074.074074
# 160         1.620000e+08             0.012860    5.677778   37851.851852
# 180         2.800000e+07             0.003086    0.797222    5314.814815
# 190         2.146667e+08             0.193930   15.363889  102425.925926
# 200         1.333333e+06             0.001543    0.033333     222.222222
# 210         1.146667e+08             6.491770   19.650000  131000.000000
#
#            landscape_shape_index  effective_mesh_size       area_mn  ...  \
# class_val                                                            ...
# 10                     48.410609         4.354211e-06  7.156359e-08  ...
# 11                     42.984375         2.979451e-09  7.057531e-09  ...
# 30                     45.453237         1.461683e-10  2.908497e-09  ...
# 40                     23.437500         1.307442e-11  1.789695e-09  ...
# 60                     31.347418         1.485103e-08  1.352396e-08  ...
# 61                      4.461538         5.278984e-13  2.109053e-09  ...
# 70                     34.395538         1.164865e-06  7.992904e-08  ...
# 90                     39.677778         3.949216e-09  8.488703e-09  ...
# 100                    46.054217         7.361841e-10  4.339410e-09  ...
# 110                     3.111111         8.228071e-12  5.941358e-09  ...
# 130                    33.099448         1.309190e-08  1.065943e-08  ...
# 150                     3.733333         1.905197e-12  3.647587e-09  ...
# 160                    17.964912         2.195343e-11  2.505335e-09  ...
# 180                     7.200000         1.107396e-12  1.708554e-09  ...
# 190                    21.676923         2.167150e-09  1.010994e-08  ...
# 200                     1.500000         3.969161e-14  1.543210e-09  ...
# 210                    14.787500         6.324757e-07  6.446041e-08  ...
#
#            fractal_dimension_md  fractal_dimension_ra  fractal_dimension_sd  \
# class_val
# 10                     0.957030              4.670052              0.225635
# 11                     0.973047              0.502692              0.073645
# 30                     0.973047              0.300865              0.043864
# 40                     0.989369              0.176982              0.029620
# 60                     0.959374              0.615752              0.078846
# 61                     0.978043              0.058134              0.023018
# 70                     0.943049              1.781737              0.165007
# 90                     0.943049              0.808231              0.077555
# 100                    0.973047              0.416200              0.058966
# 110                    0.989369              0.108503              0.038296
# 130                    0.957030              0.944643              0.082596
# 150                    0.978043              0.107895              0.033509
# 160                    0.989369              0.215230              0.039774
# 180                    0.989369              0.078080              0.027737
# 190                    0.989369              0.417617              0.076738
# 200                    0.986524              0.026953              0.013476
# 210                    0.936976              1.730105              0.154201
#
#            fractal_dimension_cv  euclidean_nearest_neighbor_mn  \
# class_val
# 10                    24.744568                       0.008370
# 11                     7.833648                       0.011556
# 30                     4.588323                       0.011982
# 40                     3.034038                       0.022241
# 60                     8.401568                       0.013584
# 61                     2.373601                       0.161615
# 70                    18.280100                       0.009463
# 90                     8.357945                       0.011890
# 100                    6.219948                       0.011663
# 110                    3.948215                       0.045304
# 130                    8.844710                       0.013517
# 150                    3.476976                       0.150434
# 160                    4.103001                       0.013635
# 180                    2.848914                       0.045749
# 190                    8.119825                       0.013747
# 200                    1.366044                       0.698085
# 210                   17.094240                       0.012234
#
#            euclidean_nearest_neighbor_am  euclidean_nearest_neighbor_md  \
# class_val
# 10                              0.005862                       0.006211
# 11                              0.008242                       0.007857
# 30                              0.011098                       0.008784
# 40                              0.022187                       0.017568
# 60                              0.009191                       0.008333
# 61                              0.142266                       0.147327
# 70                              0.006200                       0.006211
# 90                              0.008648                       0.007857
# 100                             0.009293                       0.008333
# 110                             0.034931                       0.035166
# 130                             0.007902                       0.008333
# 150                             0.105292                       0.097855
# 160                             0.011276                       0.008333
# 180                             0.048113                       0.014068
# 190                             0.009491                       0.007857
# 200                             0.698085                       0.698085
# 210                             0.006059                       0.007857
#
#            euclidean_nearest_neighbor_ra  euclidean_nearest_neighbor_sd  \
# class_val
# 10                              0.047222                       0.005190
# 11                              0.091984                       0.010312
# 30                              0.085138                       0.008416
# 40                              0.089256                       0.015864
# 60                              0.108739                       0.012621
# 61                              0.320719                       0.095403
# 70                              0.042956                       0.005896
# 90                              0.203240                       0.012602
# 100                             0.194945                       0.010168
# 110                             0.133333                       0.041490
# 130                             0.112165                       0.014217
# 150                             0.379572                       0.120555
# 160                             0.106248                       0.014380
# 180                             0.322104                       0.072557
# 190                             0.129731                       0.017556
# 200                             0.000000                       0.000000
# 210                             0.080556                       0.014371
#
#            euclidean_nearest_neighbor_cv
# class_val
# 10                             62.005784
# 11                             89.237330
# 30                             70.240400
# 40                             71.325594
# 60                             92.912773
# 61                             59.031062
# 70                             62.306570
# 90                            105.987653
# 100                            87.181509
# 110                            91.580589
# 130                           105.177926
# 150                            80.138298
# 160                           105.460092
# 180                           158.599422
# 190                           127.708438
# 200                             0.000000
# 210                           117.471461
#
# [17 rows x 45 columns]

# %%
#Calculate landscape metrics using pylandstats
landscape_metrics_df = ls.compute_landscape_metrics_df()
landscape_metrics_df
# Out:
#    total_area  number_of_patches  patch_density  largest_patch_index  \
# 0     0.00015               8004   5.336000e+09            16.328704
#
#    total_edge  edge_density  landscape_shape_index  effective_mesh_size  \
# 0     255.375     1702500.0              53.137755             0.000006
#
#         area_mn   area_am  ...  fractal_dimension_sd  fractal_dimension_cv  \
# 0  1.874063e-08  0.000006  ...              0.103597             11.027259
#
#    euclidean_nearest_neighbor_mn  euclidean_nearest_neighbor_am  \
# 0                       0.013156                       0.007027
#
#    euclidean_nearest_neighbor_md  euclidean_nearest_neighbor_ra  \
# 0                       0.008333                       0.692529
#
#    euclidean_nearest_neighbor_sd  euclidean_nearest_neighbor_cv  contagion  \
# 0                       0.019773                     150.297204  51.448827
#
#    shannon_diversity_index
# 0                 1.850287
#
# [1 rows x 46 columns]

# %% [markdown]
# ## Clipping the raster for Chernobyl for the 2010 and 2005 data

# %%
landcover_2010_path = LANDCOVER_DIR / "ESACCI-LC-L4-LCCS-Map-300m-P1Y-2010-v2.0.7.tif"
landcover_2005_path = LANDCOVER_DIR / "ESACCI-LC-L4-LCCS-Map-300m-P1Y-2005-v2.0.7.tif"

# %%
data2 = rasterio.open(landcover_2010_path)
data3 = rasterio.open(landcover_2005_path)

# %%
minx, miny = 30, 50.5
maxx, maxy = 31, 52
bbox2 = box(minx, miny, maxx, maxy)

# %%
# Give box a crs
geo = gpd.GeoDataFrame({'geometry': bbox2}, index=[0], crs="EPSG:4326")

# %%
# Make sure box crs and data crs match
geo2 = geo.to_crs(crs=data2.crs)  

geo3 = geo.to_crs(crs=data3.crs)

# %%
# Co-ordinates of polygon (box)
coords2 = getFeatures(geo2)

coords3 = getFeatures(geo3)

# %%
# Mask(crop)
out_img2, out_transform2 = mask(dataset=data2, shapes=coords2, crop=True)    #rasterio mask

out_img3, out_transform3 = mask(dataset=data3, shapes=coords3, crop=True)    #rasterio mask

# %%
# Meta data for new file
out_meta2 = data2.meta.copy()
print(out_meta2)

out_meta3 = data3.meta.copy()
print(out_meta3)
# Out:
# {'driver': 'GTiff', 'dtype': 'uint8', 'nodata': 0.0, 'width': 129600, 'height': 64800, 'count': 1, 'crs': CRS.from_epsg(4326), 'transform': Affine(0.002777777777778, 0.0, -180.0,
#        0.0, -0.002777777777778, 90.0)}
# {'driver': 'GTiff', 'dtype': 'uint8', 'nodata': 0.0, 'width': 129600, 'height': 64800, 'count': 1, 'crs': CRS.from_epsg(4326), 'transform': Affine(0.002777777777778, 0.0, -180.0,
#        0.0, -0.002777777777778, 90.0)}

# %%
epsg_code2 = int(data2.crs.data['init'][5:])     #putting crs into output data

epsg_code3 = int(data3.crs.data['init'][5:])     #putting crs into output data

# %%
# Update meta-data
out_meta2.update({"driver": "GTiff",
                 "height": out_img2.shape[1],
                 "width": out_img2.shape[2],
                 "transform": out_transform2,
                 "crs": pycrs.parse.from_epsg_code(epsg_code2).to_proj4()})

out_meta3.update({"driver": "GTiff",
                 "height": out_img3.shape[1],
                 "width": out_img3.shape[2],
                 "transform": out_transform3,
                 "crs": pycrs.parse.from_epsg_code(epsg_code3).to_proj4()})

# %%
# Write output file  
out_tif2 = r"landcover_esacci_2010_cropped1.tif"
with rasterio.open(out_tif2, "w+", **out_meta2) as dest:
    dest.write(out_img2)
    
out_tif3 = r"landcover_esacci_2005_cropped1.tif"
with rasterio.open(out_tif3, "w+", **out_meta3) as dest:
    dest.write(out_img3)

# %% [markdown]
# ## Spatio-temporal analysis of CHernobyl in 2005, 2010, 2015

# %%
#spatio-temporal analysis
input_filepaths = [
    'landcover_esacci_2015_cropped1.tif',
    'landcover_esacci_2010_cropped1.tif',
    'landcover_esacci_2005_cropped1.tif'
]

sta = pls.SpatioTemporalAnalysis(input_filepaths, dates=[2005, 2010, 2015])

# %%
#Compare class metrics in 3 years
sta.compute_class_metrics_df()
# Out:
# metric             total_area  proportion_of_landscape  number_of_patches  \
# class_val dates
# 10        2005   4.995139e-05                33.300926              698.0
#           2010   5.006327e-05                33.375514              690.0
#           2015   5.100926e-05                34.006173              625.0
# 11        2005   7.078704e-06                 4.719136             1003.0
#           2010   7.041667e-06                 4.694444              984.0
#           2015   7.010802e-06                 4.673868              958.0
# 30        2005   3.708333e-06                 2.472222             1275.0
#           2010   3.722994e-06                 2.481996             1281.0
#           2015   4.100309e-06                 2.733539             1296.0
# 40        2005   7.731481e-07                 0.515432              432.0
#           2010   8.834877e-07                 0.588992              459.0
#           2015   2.266975e-06                 1.511317              646.0
# 60        2005   8.750000e-06                 5.833333              647.0
#           2010   8.767747e-06                 5.845165              650.0
#           2015   7.848765e-06                 5.232510              576.0
# 61        2005   3.163580e-08                 0.021091               15.0
#           2010   3.163580e-08                 0.021091               15.0
#           2015   2.854938e-08                 0.019033               13.0
# 70        2005   4.675849e-05                31.172325              585.0
#           2010   4.664583e-05                31.097222              588.0
#           2015   4.593056e-05                30.620370              586.0
# 90        2005   6.247685e-06                 4.165123              736.0
#           2010   6.247685e-06                 4.165123              731.0
#           2015   6.169753e-06                 4.113169              722.0
# 100       2005   5.307099e-06                 3.538066             1223.0
#           2010   5.246914e-06                 3.497942             1218.0
#           2015   4.498457e-06                 2.998971             1072.0
# 110       2005   5.941358e-08                 0.039609               10.0
#           2010   5.941358e-08                 0.039609               10.0
#           2015   6.018519e-08                 0.040123               10.0
# 130       2005   6.267747e-06                 4.178498              588.0
#           2010   6.269290e-06                 4.179527              586.0
#           2015   6.222222e-06                 4.148148              578.0
# 150       2005   4.012346e-08                 0.026749               11.0
#           2010   4.012346e-08                 0.026749               11.0
#           2015   4.012346e-08                 0.026749               11.0
# 160       2005   6.087963e-07                 0.405864              243.0
#           2010   6.358025e-07                 0.423868              257.0
#           2015   4.074074e-07                 0.271605              150.0
# 180       2005   7.175926e-08                 0.047840               42.0
#           2010   6.944444e-08                 0.046296               40.0
#           2015   6.712963e-08                 0.044753               34.0
# 190       2005   3.255401e-06                 2.170267              322.0
#           2010   3.225309e-06                 2.150206              316.0
#           2015   3.181327e-06                 2.120885              318.0
# 200       2005   3.086420e-09                 0.002058                2.0
#           2010   3.086420e-09                 0.002058                2.0
#           2015   3.086420e-09                 0.002058                2.0
# 210       2005   1.108719e-05                 7.391461              172.0
#           2010   1.104630e-05                 7.364198              186.0
#           2015   1.115509e-05                 7.436728              187.0
#
# metric           patch_density  largest_patch_index  total_edge  \
# class_val dates
# 10        2005    4.653333e+08            16.328704  134.902778
#           2010    4.600000e+08            16.298354  134.997222
#           2015    4.166667e+08            16.670267  136.363889
# 11        2005    6.686667e+08             0.172325   45.516667
#           2010    6.560000e+08             0.172325   45.161111
#           2015    6.386667e+08             0.172325   44.772222
# 30        2005    8.500000e+08             0.028807   34.950000
#           2010    8.540000e+08             0.028807   35.113889
#           2015    8.640000e+08             0.036008   37.752778
# 40        2005    2.880000e+08             0.006687    8.311111
#           2010    3.060000e+08             0.007202    9.097222
#           2015    4.306667e+08             0.052984   17.336111
# 60        2005    4.313333e+08             0.711934   36.650000
#           2010    4.333333e+08             0.711934   36.758333
#           2015    3.840000e+08             0.670782   32.700000
# 61        2005    1.000000e+07             0.003086    0.322222
#           2010    1.000000e+07             0.003086    0.322222
#           2015    8.666667e+06             0.003086    0.288889
# 70        2005    3.900000e+08             6.181584   92.938889
#           2010    3.920000e+08             6.158951   92.780556
#           2015    3.906667e+08             6.973251   90.886111
# 90        2005    4.906667e+08             0.411008   39.450000
#           2010    4.873333e+08             0.411008   39.405556
#           2015    4.813333e+08             0.410494   38.911111
# 100       2005    8.153333e+08             0.079733   42.363889
#           2010    8.120000e+08             0.079733   41.983333
#           2015    7.146667e+08             0.079733   36.136111
# 110       2005    6.666667e+06             0.016975    0.311111
#           2010    6.666667e+06             0.016975    0.311111
#           2015    6.666667e+06             0.016975    0.316667
# 130       2005    3.920000e+08             0.754115   33.200000
#           2010    3.906667e+08             0.752572   33.225000
#           2015    3.853333e+08             0.752058   33.088889
# 150       2005    7.333333e+06             0.008230    0.311111
#           2010    7.333333e+06             0.008230    0.311111
#           2015    7.333333e+06             0.008230    0.311111
# 160       2005    1.620000e+08             0.012860    5.677778
#           2010    1.713333e+08             0.012860    5.922222
#           2015    1.000000e+08             0.012860    3.761111
# 180       2005    2.800000e+07             0.003086    0.797222
#           2010    2.666667e+07             0.003086    0.769444
#           2015    2.266667e+07             0.004115    0.736111
# 190       2005    2.146667e+08             0.193930   15.363889
#           2010    2.106667e+08             0.192387   15.213889
#           2015    2.120000e+08             0.190329   15.083333
# 200       2005    1.333333e+06             0.001543    0.033333
#           2010    1.333333e+06             0.001543    0.033333
#           2015    1.333333e+06             0.001543    0.033333
# 210       2005    1.146667e+08             6.491770   19.650000
#           2010    1.240000e+08             5.992284   19.661111
#           2015    1.246667e+08             6.069959   19.522222
#
# metric            edge_density  landscape_shape_index  effective_mesh_size  \
# class_val dates
# 10        2005   899351.851852              48.410609         4.354211e-06
#           2010   899981.481481              48.349020         4.341859e-06
#           2015   909092.592593              48.365049         4.537285e-06
# 11        2005   303444.444444              42.984375         2.979451e-09
#           2010   301074.074074              42.651042         2.977855e-09
#           2015   298481.481481              42.507853         2.977760e-09
# 30        2005   233000.000000              45.453237         1.461683e-10
#           2010   234092.592593              45.661871         1.461961e-10
#           2015   251685.185185              46.732877         1.814462e-10
# 40        2005    55407.407407              23.437500         1.307442e-11
#           2010    60648.148148              24.147059         1.710312e-11
#           2015   115574.074074              28.733945         1.843675e-10
# 60        2005   244333.333333              31.347418         1.485103e-08
#           2010   245055.555556              31.294393         1.488411e-08
#           2015   218000.000000              29.509901         1.339489e-08
# 61        2005     2148.148148               4.461538         5.278984e-13
#           2010     2148.148148               4.461538         5.278984e-13
#           2015     1925.925926               4.000000         4.961452e-13
# 70        2005   619592.592593              34.395538         1.164865e-06
#           2010   618537.037037              34.410569         1.123954e-06
#           2015   605907.407407              33.985656         1.246868e-06
# 90        2005   263000.000000              39.677778         3.949216e-09
#           2010   262703.703704              39.633333         3.951137e-09
#           2015   259407.407407              39.357542         3.913267e-09
# 100       2005   282425.925926              46.054217         7.361841e-10
#           2010   279888.888889              45.915152         7.033989e-10
#           2015   240907.407407              42.627451         5.795293e-10
# 110       2005     2074.074074               3.111111         8.228071e-12
#           2010     2074.074074               3.111111         8.228071e-12
#           2015     2111.111111               3.166667         8.239979e-12
# 130       2005   221333.333333              33.099448         1.309190e-08
#           2010   221500.000000              33.127072         1.306181e-08
#           2015   220592.592593              33.177778         1.252424e-08
# 150       2005     2074.074074               3.733333         1.905197e-12
#           2010     2074.074074               3.733333         1.905197e-12
#           2015     2074.074074               3.733333         1.905197e-12
# 160       2005    37851.851852              17.964912         2.195343e-11
#           2010    39481.481481              18.413793         2.324341e-11
#           2015    25074.074074              14.739130         1.606716e-11
# 180       2005     5314.814815               7.200000         1.107396e-12
#           2010     5129.629630               7.315789         1.087550e-12
#           2015     4907.407407               7.000000         1.202656e-12
# 190       2005   102425.925926              21.676923         2.167150e-09
#           2010   101425.925926              21.453846         2.136258e-09
#           2015   100555.555556              21.434109         2.083964e-09
# 200       2005      222.222222               1.500000         3.969161e-14
#           2010      222.222222               1.500000         3.969161e-14
#           2015      222.222222               1.500000         3.969161e-14
# 210       2005   131000.000000              14.787500         6.324757e-07
#           2010   131074.074074              14.795833         5.406244e-07
#           2015   130148.148148              14.630705         5.546729e-07
#
# metric                area_mn  ...  fractal_dimension_md  \
# class_val dates                ...
# 10        2005   7.156359e-08  ...              0.957030
#           2010   7.255547e-08  ...              0.958202
#           2015   8.161481e-08  ...              0.957030
# 11        2005   7.057531e-09  ...              0.973047
#           2010   7.156165e-09  ...              0.973047
#           2015   7.318165e-09  ...              0.959374
# 30        2005   2.908497e-09  ...              0.973047
#           2010   2.906318e-09  ...              0.973047
#           2015   3.163818e-09  ...              0.973047
# 40        2005   1.789695e-09  ...              0.989369
#           2010   1.924810e-09  ...              0.989369
#           2015   3.509250e-09  ...              0.988519
# 60        2005   1.352396e-08  ...              0.959374
#           2010   1.348884e-08  ...              0.959374
#           2015   1.362633e-08  ...              0.957030
# 61        2005   2.109053e-09  ...              0.978043
#           2010   2.109053e-09  ...              0.978043
#           2015   2.196106e-09  ...              0.973047
# 70        2005   7.992904e-08  ...              0.943049
#           2010   7.932965e-08  ...              0.943643
#           2015   7.837979e-08  ...              0.943652
# 90        2005   8.488703e-09  ...              0.943049
#           2010   8.546765e-09  ...              0.942163
#           2015   8.545364e-09  ...              0.942606
# 100       2005   4.339410e-09  ...              0.973047
#           2010   4.307811e-09  ...              0.973047
#           2015   4.196322e-09  ...              0.973047
# 110       2005   5.941358e-09  ...              0.989369
#           2010   5.941358e-09  ...              0.989369
#           2015   6.018519e-09  ...              0.989369
# 130       2005   1.065943e-08  ...              0.957030
#           2010   1.069845e-08  ...              0.957030
#           2015   1.076509e-08  ...              0.943457
# 150       2005   3.647587e-09  ...              0.978043
#           2010   3.647587e-09  ...              0.978043
#           2015   3.647587e-09  ...              0.978043
# 160       2005   2.505335e-09  ...              0.989369
#           2010   2.473940e-09  ...              0.989369
#           2015   2.716049e-09  ...              0.982946
# 180       2005   1.708554e-09  ...              0.989369
#           2010   1.736111e-09  ...              0.989369
#           2015   1.974401e-09  ...              0.981208
# 190       2005   1.010994e-08  ...              0.989369
#           2010   1.020667e-08  ...              0.974424
#           2015   1.000417e-08  ...              0.974424
# 200       2005   1.543210e-09  ...              0.986524
#           2010   1.543210e-09  ...              0.986524
#           2015   1.543210e-09  ...              0.986524
# 210       2005   6.446041e-08  ...              0.936976
#           2010   5.938869e-08  ...              0.937436
#           2015   5.965290e-08  ...              0.937436
#
# metric           fractal_dimension_ra  fractal_dimension_sd  \
# class_val dates
# 10        2005               4.670052              0.225635
#           2010               4.658325              0.227158
#           2015               4.752054              0.241341
# 11        2005               0.502692              0.073645
#           2010               0.502692              0.073985
#           2015               0.502692              0.074422
# 30        2005               0.300865              0.043864
#           2010               0.300865              0.043876
#           2015               0.311439              0.045356
# 40        2005               0.176982              0.029620
#           2010               0.176982              0.028954
#           2015               0.236587              0.039553
# 60        2005               0.615752              0.078846
#           2010               0.615752              0.078602
#           2015               0.613238              0.076738
# 61        2005               0.058134              0.023018
#           2010               0.058134              0.023018
#           2015               0.058134              0.023305
# 70        2005               1.781737              0.165007
#           2010               1.777304              0.164045
#           2015               1.955433              0.164566
# 90        2005               0.808231              0.077555
#           2010               0.808231              0.077649
#           2015               0.806496              0.078078
# 100       2005               0.416200              0.058966
#           2010               0.416200              0.058548
#           2015               0.416200              0.056098
# 110       2005               0.108503              0.038296
#           2010               0.108503              0.038296
#           2015               0.108503              0.037588
# 130       2005               0.944643              0.082596
#           2010               0.941854              0.082610
#           2015               0.941863              0.082550
# 150       2005               0.107895              0.033509
#           2010               0.107895              0.033509
#           2015               0.107895              0.033509
# 160       2005               0.215230              0.039774
#           2010               0.215230              0.039095
#           2015               0.215230              0.040702
# 180       2005               0.078080              0.027737
#           2010               0.078080              0.027982
#           2015               0.137631              0.033380
# 190       2005               0.417617              0.076738
#           2010               0.417617              0.076499
#           2015               0.414045              0.075694
# 200       2005               0.026953              0.013476
#           2010               0.026953              0.013476
#           2015               0.026953              0.013476
# 210       2005               1.730105              0.154201
#           2010               1.405873              0.141818
#           2015               1.392990              0.140477
#
# metric           fractal_dimension_cv  euclidean_nearest_neighbor_mn  \
# class_val dates
# 10        2005              24.744568                       0.008370
#           2010              24.910624                       0.008408
#           2015              26.670816                       0.008594
# 11        2005               7.833648                       0.011556
#           2010               7.876272                       0.011625
#           2015               7.934022                       0.011645
# 30        2005               4.588323                       0.011982
#           2010               4.589752                       0.011919
#           2015               4.762887                       0.011711
# 40        2005               3.034038                       0.022241
#           2010               2.967422                       0.021495
#           2015               4.092521                       0.016154
# 60        2005               8.401568                       0.013584
#           2010               8.377752                       0.013372
#           2015               8.188557                       0.014297
# 61        2005               2.373601                       0.161615
#           2010               2.373601                       0.161615
#           2015               2.410651                       0.193662
# 70        2005              18.280100                       0.009463
#           2010              18.157589                       0.009439
#           2015              18.171968                       0.009567
# 90        2005               8.357945                       0.011890
#           2010               8.372075                       0.011918
#           2015               8.417741                       0.011668
# 100       2005               6.219948                       0.011663
#           2010               6.174530                       0.011567
#           2015               5.910858                       0.012875
# 110       2005               3.948215                       0.045304
#           2010               3.948215                       0.045304
#           2015               3.879471                       0.045620
# 130       2005               8.844710                       0.013517
#           2010               8.852282                       0.013529
#           2015               8.862721                       0.013491
# 150       2005               3.476976                       0.150434
#           2010               3.476976                       0.150434
#           2015               3.476976                       0.150434
# 160       2005               4.103001                       0.013635
#           2010               4.029673                       0.013834
#           2015               4.224175                       0.021079
# 180       2005               2.848914                       0.045749
#           2010               2.877252                       0.050000
#           2015               3.462068                       0.060030
# 190       2005               8.119825                       0.013747
#           2010               8.103197                       0.014087
#           2015               8.009213                       0.014219
# 200       2005               1.366044                       0.698085
#           2010               1.366044                       0.698085
#           2015               1.366044                       0.698085
# 210       2005              17.094240                       0.012234
#           2010              15.728543                       0.011794
#           2015              15.570279                       0.011716
#
# metric           euclidean_nearest_neighbor_am  euclidean_nearest_neighbor_md  \
# class_val dates
# 10        2005                        0.005862                       0.006211
#           2010                        0.005863                       0.006211
#           2015                        0.005909                       0.006211
# 11        2005                        0.008242                       0.007857
#           2010                        0.008267                       0.007857
#           2015                        0.008167                       0.007857
# 30        2005                        0.011098                       0.008784
#           2010                        0.011038                       0.008784
#           2015                        0.010585                       0.008784
# 40        2005                        0.022187                       0.017568
#           2010                        0.021305                       0.016667
#           2015                        0.014362                       0.011453
# 60        2005                        0.009191                       0.008333
#           2010                        0.009149                       0.008333
#           2015                        0.009792                       0.008784
# 61        2005                        0.142266                       0.147327
#           2010                        0.142266                       0.147327
#           2015                        0.166471                       0.206473
# 70        2005                        0.006200                       0.006211
#           2010                        0.006150                       0.006211
#           2015                        0.006190                       0.007857
# 90        2005                        0.008648                       0.007857
#           2010                        0.008695                       0.007857
#           2015                        0.008662                       0.007857
# 100       2005                        0.009293                       0.008333
#           2010                        0.009249                       0.008333
#           2015                        0.010174                       0.008784
# 110       2005                        0.034931                       0.035166
#           2010                        0.034931                       0.035166
#           2015                        0.033269                       0.011111
# 130       2005                        0.007902                       0.008333
#           2010                        0.007899                       0.008333
#           2015                        0.007910                       0.008333
# 150       2005                        0.105292                       0.097855
#           2010                        0.105292                       0.097855
#           2015                        0.105292                       0.097855
# 160       2005                        0.011276                       0.008333
#           2010                        0.012117                       0.008333
#           2015                        0.016908                       0.008559
# 180       2005                        0.048113                       0.014068
#           2010                        0.053697                       0.012423
#           2015                        0.062056                       0.015713
# 190       2005                        0.009491                       0.007857
#           2010                        0.009661                       0.007857
#           2015                        0.009714                       0.007857
# 200       2005                        0.698085                       0.698085
#           2010                        0.698085                       0.698085
#           2015                        0.698085                       0.698085
# 210       2005                        0.006059                       0.007857
#           2010                        0.006061                       0.007857
#           2015                        0.006055                       0.007857
#
# metric           euclidean_nearest_neighbor_ra  euclidean_nearest_neighbor_sd  \
# class_val dates
# 10        2005                        0.047222                       0.005190
#           2010                        0.047222                       0.005203
#           2015                        0.047222                       0.005662
# 11        2005                        0.091984                       0.010312
#           2010                        0.091984                       0.010647
#           2015                        0.111045                       0.010920
# 30        2005                        0.085138                       0.008416
#           2010                        0.085138                       0.008242
#           2015                        0.085138                       0.008061
# 40        2005                        0.089256                       0.015864
#           2010                        0.089256                       0.016598
#           2015                        0.088151                       0.013080
# 60        2005                        0.108739                       0.012621
#           2010                        0.108739                       0.012462
#           2015                        0.108739                       0.012842
# 61        2005                        0.320719                       0.095403
#           2010                        0.320719                       0.095403
#           2015                        0.378004                       0.126251
# 70        2005                        0.042956                       0.005896
#           2010                        0.042956                       0.005884
#           2015                        0.042956                       0.005973
# 90        2005                        0.203240                       0.012602
#           2010                        0.203240                       0.012708
#           2015                        0.203240                       0.012283
# 100       2005                        0.194945                       0.010168
#           2010                        0.194945                       0.010032
#           2015                        0.194945                       0.011092
# 110       2005                        0.133333                       0.041490
#           2010                        0.133333                       0.041490
#           2015                        0.166843                       0.054932
# 130       2005                        0.112165                       0.014217
#           2010                        0.112165                       0.014243
#           2015                        0.112165                       0.014154
# 150       2005                        0.379572                       0.120555
#           2010                        0.379572                       0.120555
#           2015                        0.379572                       0.120555
# 160       2005                        0.106248                       0.014380
#           2010                        0.192214                       0.018789
#           2015                        0.285157                       0.041111
# 180       2005                        0.322104                       0.072557
#           2010                        0.477187                       0.090613
#           2015                        0.576381                       0.108577
# 190       2005                        0.129731                       0.017556
#           2010                        0.129731                       0.018231
#           2015                        0.136084                       0.018905
# 200       2005                        0.000000                       0.000000
#           2010                        0.000000                       0.000000
#           2015                        0.000000                       0.000000
# 210       2005                        0.080556                       0.014371
#           2010                        0.080556                       0.013911
#           2015                        0.080556                       0.013824
#
# metric           euclidean_nearest_neighbor_cv
# class_val dates
# 10        2005                       62.005784
#           2010                       61.879486
#           2015                       65.885507
# 11        2005                       89.237330
#           2010                       91.590504
#           2015                       93.772185
# 30        2005                       70.240400
#           2010                       69.147390
#           2015                       68.832844
# 40        2005                       71.325594
#           2010                       77.217451
#           2015                       80.971730
# 60        2005                       92.912773
#           2010                       93.200204
#           2015                       89.823074
# 61        2005                       59.031062
#           2010                       59.031062
#           2015                       65.191253
# 70        2005                       62.306570
#           2010                       62.343080
#           2015                       62.430385
# 90        2005                      105.987653
#           2010                      106.624781
#           2015                      105.264903
# 100       2005                       87.181509
#           2010                       86.734342
#           2015                       86.148639
# 110       2005                       91.580589
#           2010                       91.580589
#           2015                      120.411038
# 130       2005                      105.177926
#           2010                      105.277540
#           2015                      104.911140
# 150       2005                       80.138298
#           2010                       80.138298
#           2015                       80.138298
# 160       2005                      105.460092
#           2010                      135.815720
#           2015                      195.036285
# 180       2005                      158.599422
#           2010                      181.225235
#           2015                      180.871249
# 190       2005                      127.708438
#           2010                      129.417657
#           2015                      132.962195
# 200       2005                        0.000000
#           2010                        0.000000
#           2015                        0.000000
# 210       2005                      117.471461
#           2010                      117.944576
#           2015                      117.990681
#
# [51 rows x 45 columns]

# %%
#Compare the landscape metrics in 3 years
sta.compute_landscape_metrics_df()
# Out:
# metric  total_area  number_of_patches  patch_density  largest_patch_index  \
# dates
# 2005       0.00015             8004.0   5.336000e+09            16.328704
# 2010       0.00015             8024.0   5.349333e+09            16.298354
# 2015       0.00015             7784.0   5.189333e+09            16.670267
#
# metric  total_edge  edge_density  landscape_shape_index  effective_mesh_size  \
# dates
# 2005    255.375000  1.702500e+06              53.137755             0.000006
# 2010    255.533333  1.703556e+06              53.170068             0.000006
# 2015    254.000000  1.693333e+06              52.857143             0.000006
#
# metric       area_mn   area_am  ...  fractal_dimension_sd  \
# dates                           ...
# 2005    1.874063e-08  0.000006  ...              0.103597
# 2010    1.869392e-08  0.000006  ...              0.103145
# 2015    1.927030e-08  0.000006  ...              0.104453
#
# metric  fractal_dimension_cv  euclidean_nearest_neighbor_mn  \
# dates
# 2005               11.027259                       0.013156
# 2010               10.979657                       0.013145
# 2015               11.137867                       0.013354
#
# metric  euclidean_nearest_neighbor_am  euclidean_nearest_neighbor_md  \
# dates
# 2005                         0.007027                       0.008333
# 2010                         0.007024                       0.008333
# 2015                         0.007113                       0.008333
#
# metric  euclidean_nearest_neighbor_ra  euclidean_nearest_neighbor_sd  \
# dates
# 2005                         0.692529                       0.019773
# 2010                         0.692529                       0.020292
# 2015                         0.692529                       0.021804
#
# metric  euclidean_nearest_neighbor_cv  contagion  shannon_diversity_index
# dates
# 2005                       150.297204  51.448827                 1.850287
# 2010                       154.373380  51.406524                 1.852077
# 2015                       163.276315  51.344139                 1.858602
#
# [3 rows x 46 columns]

# %%
#the evolution of the proportion of landscape occupied by the land use class value 10
sta.plot_metric('proportion_of_landscape', class_val=10)
# Out:
# <AxesSubplot:ylabel='PLAND'>

# %%
#the number of patches in Chernobyl from 2005 to 2015
sta.plot_metric('number_of_patches')
# Out:
# <AxesSubplot:ylabel='NP'>
